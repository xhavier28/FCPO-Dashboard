# %% [markdown]
# # Stage 1 — P&L Backtest
#
# MR calendar spread strategy: M2-M3, M3-M4, M4-M5, M5-M6.
# All instruments use dur>=10d (per Part 1 decision table).
#
# Entry/exit/sizing/cost rules per specification.
# Full implementation in `stage1_pnl_backtest.py`.

# %%
# %run stage1_pnl_backtest.py
